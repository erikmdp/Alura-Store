# %% [markdown]
# <a href="https://colab.research.google.com/github/erikmdp/Alura-Store/blob/main/AluraStore_Erik_Kees.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda1 = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda1.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# 1  Tarjeta de crédito                   4   6.25184 -75.56359
# 2  Tarjeta de crédito                   1  10.39972 -75.51444
# 3               Nequi                   1   3.43722 -76.52250
# 4               Nequi                   1   6.25184 -75.56359

# %% [markdown]
# #1. Análisis de facturación

# %%
total_tienda1 = sum(tienda1['Precio'])    #sumo la columna de precios para cada tienda
total_tienda2 = sum(tienda2['Precio'])
total_tienda3 = sum(tienda3['Precio'])
total_tienda4 = sum(tienda4['Precio'])

ventas = [total_tienda1, total_tienda2, total_tienda3, total_tienda4]
tiendas = ['tienda1', 'tienda2', 'tienda3', 'tienda4']

print(ventas)
# Out:
# [1150880400.0, 1116343500.0, 1098019600.0, 1038375700.0]

# %%
import matplotlib.pyplot as plt
plt.bar(tiendas, ventas, color=['red', 'blue', 'green', 'yellow'])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.pie(ventas, labels=tiendas, autopct='%1.1f%%')
plt.title('Ventas por tienda')
plt.axis('equal')
plt.show()

# %% [markdown]
# # 2. Ventas por categoría

# %%
#  Comencé calculando la cantidad de productos tienda por tienda  #
#  y me dí cuenta que podría hacer una función e iterar sobre     #
#  cada tienda al incluirlas en un diccionario.                   #

conteo1 = {}

for venta in tienda1.to_dict('records'):        #itero sobre cada linea de la tabla, convirtiendo en listas de diccionarios
  categoria = venta['Categoría del Producto']   #Extraigo la categoría del producto
  if categoria in conteo1:
    conteo1[categoria] += 1                      #Actualizo la cantidad de productos para esa categoría
  else:
    conteo1[categoria] = 1                       #Creo una nueva entrada para la categoía que todavía no había sido leída

print(conteo1)


conteo2 = {}

for venta in tienda2.to_dict('records'):
  categoria = venta['Categoría del Producto']
  if categoria in conteo2:
    conteo2[categoria] += 1
  else:
    conteo2[categoria] = 1

print(conteo2)


conteo3 = {}

for venta in tienda3.to_dict('records'):
  categoria = venta['Categoría del Producto']
  if categoria in conteo3:
    conteo3[categoria] += 1
  else:
    conteo3[categoria] = 1

print(conteo3)


conteo4 = {}

for venta in tienda4.to_dict('records'):
  categoria = venta['Categoría del Producto']
  if categoria in conteo4:
    conteo4[categoria] += 1
  else:
    conteo4[categoria] = 1

print(conteo4)
# Out:
# {'Electrónicos': 448, 'Muebles': 465, 'Juguetes': 324, 'Electrodomésticos': 312, 'Artículos para el hogar': 171, 'Deportes y diversión': 284, 'Libros': 173, 'Instrumentos musicales': 182}
# {'Muebles': 442, 'Instrumentos musicales': 224, 'Deportes y diversión': 275, 'Electrónicos': 422, 'Artículos para el hogar': 181, 'Juguetes': 313, 'Electrodomésticos': 305, 'Libros': 197}
# {'Electrodomésticos': 278, 'Muebles': 499, 'Instrumentos musicales': 177, 'Deportes y diversión': 277, 'Electrónicos': 451, 'Juguetes': 315, 'Artículos para el hogar': 177, 'Libros': 185}
# {'Electrodomésticos': 254, 'Muebles': 480, 'Deportes y diversión': 277, 'Libros': 187, 'Electrónicos': 451, 'Instrumentos musicales': 170, 'Juguetes': 338, 'Artículos para el hogar': 201}

# %%
#  Código mejorado usando la función contar_categorías  #


def contar_categorias(tienda):
    conteo = {}
    for venta in tienda.to_dict('records'):
        categoria = venta['Categoría del Producto']
        if categoria in conteo:
            conteo[categoria] += 1
        else:
            conteo[categoria] = 1
    return conteo


#  Creo un diccionario para iterar sobre las tiendas  #
tiendas = {'Tienda 1': tienda1,'Tienda 2': tienda2,'Tienda 3': tienda3,'Tienda 4': tienda4}

#  Creo un diccionario con los resultados  #
resultados = {nombre: contar_categorias(datos) for nombre, datos in tiendas.items()}

#  Visualizo los datos  #
print(resultados)
print("----------------------------------------------")
for tienda, conteo in resultados.items():
    print(f"\n{tienda}:")
    for categoria, cantidad in conteo.items():
        print(f"  {categoria}: {cantidad} productos")
# Out:
# {'Tienda 1': {'Electrónicos': 448, 'Muebles': 465, 'Juguetes': 324, 'Electrodomésticos': 312, 'Artículos para el hogar': 171, 'Deportes y diversión': 284, 'Libros': 173, 'Instrumentos musicales': 182}, 'Tienda 2': {'Muebles': 442, 'Instrumentos musicales': 224, 'Deportes y diversión': 275, 'Electrónicos': 422, 'Artículos para el hogar': 181, 'Juguetes': 313, 'Electrodomésticos': 305, 'Libros': 197}, 'Tienda 3': {'Electrodomésticos': 278, 'Muebles': 499, 'Instrumentos musicales': 177, 'Deportes y diversión': 277, 'Electrónicos': 451, 'Juguetes': 315, 'Artículos para el hogar': 177, 'Libros': 185}, 'Tienda 4': {'Electrodomésticos': 254, 'Muebles': 480, 'Deportes y diversión': 277, 'Libros': 187, 'Electrónicos': 451, 'Instrumentos musicales': 170, 'Juguetes': 338, 'Artículos para el hogar': 201}}
# ----------------------------------------------
#
# Tienda 1:
#   Electrónicos: 448 productos
#   Muebles: 465 productos
#   Juguetes: 324 productos
#   Electrodomésticos: 312 productos
#   Artículos para el hogar: 171 productos
#   Deportes y diversión: 284 productos
#   Libros: 173 productos
#   Instrumentos musicales: 182 productos
#
# Tienda 2:
#   Muebles: 442 productos
#   Instrumentos musicales: 224 productos
#   Deportes y diversión: 275 productos
#   Electrónicos: 422 productos
#   Artículos para el hogar: 181 productos
#   Juguetes: 313 productos
#   Electrodomésticos: 305 productos
#   Libros: 197 productos
#
# Tienda 3:
#   Electrodomésticos: 278 productos
#   Muebles: 499 productos
#   Instrumentos musicales: 177 productos
#   Deportes y diversión: 277 productos
#   Electrónicos: 451 productos
#   Juguetes: 315 productos
#   Artículos para el hogar: 177 productos
#   Libros: 185 productos
#
# Tienda 4:
#   Electrodomésticos: 254 productos
#   Muebles: 480 productos
#   Deportes y diversión: 277 productos
#   Libros: 187 productos
#   Electrónicos: 451 productos
#   Instrumentos musicales: 170 productos
#   Juguetes: 338 productos
#   Artículos para el hogar: 201 productos

# %%
#visualizo los datos de las categorías mas populares por cada tienda
import matplotlib.pyplot as plt

for tienda, categorias in resultados.items():
    # Ordeno categorías por cantidad (de mayor a menor)
    categorias_ordenadas = sorted(categorias.items(), key=lambda x: x[1], reverse=True)
    nombres = [cat[0] for cat in categorias_ordenadas]
    valores = [cat[1] for cat in categorias_ordenadas]

    # Creo el gráfico
    plt.figure(figsize=(10, 5))
    plt.bar(nombres, valores, color='skyblue')
    plt.title(f'Categorías más populares en {tienda}')
    plt.xlabel('Categoría')
    plt.ylabel('Cantidad de productos vendidos')
    plt.xticks(rotation=45)  #para que no se solapen los nombres de las categorías
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
def calcular_promedio(tienda):
  for venta in tienda.to_dict('records'):
    suma = sum(tienda["Calificación"])
    n = len(tienda["Calificación"])
  promedio = suma/n
  return round(promedio,2)


tiendas = {'Tienda 1': tienda1,'Tienda 2': tienda2,'Tienda 3': tienda3,'Tienda 4': tienda4}

print(calcular_promedio(tienda1))

promedios = {nombre: calcular_promedio(datos) for nombre, datos in tiendas.items()}
print(promedios)
# Out:
# 3.98
# {'Tienda 1': 3.98, 'Tienda 2': 4.04, 'Tienda 3': 4.05, 'Tienda 4': 4.0}

# %%
import matplotlib.pyplot as plt
plt.bar(promedios.keys(), promedios.values(), color=['red', 'blue', 'green', 'yellow'])
plt.show()

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
def contar_productos(tienda):
    conteo = {}
    for venta in tienda.to_dict('records'):
        producto = venta['Producto']
        if producto in conteo:
            conteo[producto] += 1
        else:
            conteo[producto] = 1
    return conteo


#  Creo un diccionario para iterar sobre las tiendas  #
tiendas = {'Tienda 1': tienda1,'Tienda 2': tienda2,'Tienda 3': tienda3,'Tienda 4': tienda4}

#  Creo un diccionario con los resultados  #
resultados = {nombre: contar_productos(datos) for nombre, datos in tiendas.items()}

#  Visualizo los datos  #
print(resultados)
print("----------------------------------------------")
for tienda, conteo in resultados.items():
    print(f"\n{tienda}:")
    for producto, cantidad in conteo.items():
        print(f"  {producto}: {cantidad} unidades")
# Out:
# {'Tienda 1': {'Asistente virtual': 40, 'Mesa de comedor': 40, 'Juego de mesa': 43, 'Microondas': 60, 'Silla de oficina': 46, 'Bloques de construcción': 56, 'Muñeca bebé': 40, 'Lavavajillas': 48, 'Lavadora de ropa': 47, 'Carrito de control remoto': 52, 'Refrigerador': 54, 'Auriculares': 50, 'Olla de presión': 35, 'Bicicleta': 54, 'Ciencia de datos con Python': 39, 'Balón de voleibol': 42, 'Ajedrez de madera': 49, 'TV LED UHD 4K': 60, 'Vaso térmico': 54, 'Kit de bancas': 44, 'Dashboards con Power BI': 42, 'Cubertería': 52, 'Set de ollas': 43, 'Batería': 53, 'Cuerda para saltar': 40, 'Estufa': 45, 'Cama box': 44, 'Impresora': 54, 'Mesa de noche': 56, 'Armario': 60, 'Dinosaurio Rex': 40, 'Guitarra eléctrica': 47, 'Secadora de ropa': 58, 'Sofá reclinable': 46, 'Tablet ABXY': 42, 'Cubo mágico 8x8': 44, 'Set de vasos': 41, 'Modelado predictivo': 51, 'Iphone 15': 49, 'Mochila': 39, 'Balón de baloncesto': 55, 'Auriculares con micrófono': 33, 'Sillón': 41, 'Guitarra acústica': 46, 'Iniciando en programación': 41, 'Celular ABXY': 33, 'Smartwatch': 43, 'Mesa de centro': 44, 'Cama king': 44, 'Smart TV': 44, 'Pandereta': 36}, 'Tienda 2': {'Silla de oficina': 49, 'Pandereta': 58, 'Cama king': 45, 'Guitarra acústica': 58, 'Mochila': 45, 'Tablet ABXY': 44, 'Olla de presión': 44, 'Cubo mágico 8x8': 45, 'Secadora de ropa': 57, 'Juego de mesa': 32, 'Ajedrez de madera': 45, 'Bicicleta': 45, 'Modelado predictivo': 46, 'Dashboards con Power BI': 43, 'Cuerda para saltar': 50, 'Set de vasos': 46, 'Muñeca bebé': 48, 'Ciencia de datos con Python': 43, 'Lavavajillas': 46, 'Bloques de construcción': 54, 'Vaso térmico': 47, 'Cubertería': 39, 'Estufa': 42, 'Set de ollas': 52, 'TV LED UHD 4K': 45, 'Sillón': 35, 'Guitarra eléctrica': 47, 'Auriculares con micrófono': 44, 'Dinosaurio Rex': 42, 'Smart TV': 40, 'Armario': 54, 'Refrigerador': 49, 'Mesa de centro': 45, 'Lavadora de ropa': 49, 'Batería': 61, 'Celular ABXY': 41, 'Balón de baloncesto': 42, 'Mesa de comedor': 34, 'Kit de bancas': 45, 'Cama box': 47, 'Balón de voleibol': 46, 'Asistente virtual': 38, 'Sofá reclinable': 44, 'Carrito de control remoto': 47, 'Auriculares': 37, 'Microondas': 62, 'Smartwatch': 44, 'Iniciando en programación': 65, 'Mesa de noche': 44, 'Impresora': 34, 'Iphone 15': 55}, 'Tienda 3': {'Secadora de ropa': 45, 'Mesa de noche': 55, 'Guitarra acústica': 47, 'Balón de voleibol': 48, 'Armario': 49, 'Impresora': 50, 'Carrito de control remoto': 52, 'Silla de oficina': 46, 'Pandereta': 51, 'Cubertería': 39, 'Muñeca bebé': 39, 'Auriculares': 43, 'Set de vasos': 36, 'TV LED UHD 4K': 42, 'Olla de presión': 47, 'Lavadora de ropa': 42, 'Set de ollas': 55, 'Dinosaurio Rex': 46, 'Modelado predictivo': 53, 'Mesa de comedor': 56, 'Dashboards con Power BI': 40, 'Kit de bancas': 57, 'Cuerda para saltar': 53, 'Iniciando en programación': 46, 'Balón de baloncesto': 50, 'Estufa': 53, 'Bicicleta': 52, 'Lavavajillas': 52, 'Smart TV': 54, 'Mochila': 36, 'Tablet ABXY': 48, 'Mesa de centro': 42, 'Cama box': 46, 'Ajedrez de madera': 47, 'Iphone 15': 46, 'Cama king': 56, 'Smartwatch': 46, 'Ciencia de datos con Python': 46, 'Refrigerador': 50, 'Auriculares con micrófono': 39, 'Juego de mesa': 52, 'Batería': 41, 'Guitarra eléctrica': 38, 'Sofá reclinable': 45, 'Sillón': 47, 'Asistente virtual': 39, 'Vaso térmico': 38, 'Celular ABXY': 44, 'Microondas': 36, 'Cubo mágico 8x8': 44, 'Bloques de construcción': 35}, 'Tienda 4': {'Lavavajillas': 43, 'Cama box': 62, 'Balón de baloncesto': 50, 'Modelado predictivo': 50, 'Auriculares': 44, 'Refrigerador': 38, 'Guitarra eléctrica': 33, 'Auriculares con micrófono': 42, 'Iphone 15': 48, 'Mesa de noche': 55, 'Muñeca bebé': 48, 'Dashboards con Power BI': 56, 'Silla de oficina': 40, 'Kit de bancas': 42, 'Impresora': 50, 'Set de vasos': 46, 'Mesa de comedor': 55, 'Carrito de control remoto': 55, 'Cuerda para saltar': 43, 'Estufa': 47, 'Cama king': 56, 'Balón de voleibol': 48, 'Secadora de ropa': 40, 'Dinosaurio Rex': 47, 'TV LED UHD 4K': 40, 'Vaso térmico': 48, 'Smart TV': 54,  ...
# ----------------------------------------------
#
# Tienda 1:
#   Asistente virtual: 40 unidades
#   Mesa de comedor: 40 unidades
#   Juego de mesa: 43 unidades
#   Microondas: 60 unidades
#   Silla de oficina: 46 unidades
#   Bloques de construcción: 56 unidades
#   Muñeca bebé: 40 unidades
#   Lavavajillas: 48 unidades
#   Lavadora de ropa: 47 unidades
#   Carrito de control remoto: 52 unidades
#   Refrigerador: 54 unidades
#   Auriculares: 50 unidades
#   Olla de presión: 35 unidades
#   Bicicleta: 54 unidades
#   Ciencia de datos con Python: 39 unidades
#   Balón de voleibol: 42 unidades
#   Ajedrez de madera: 49 unidades
#   TV LED UHD 4K: 60 unidades
#   Vaso térmico: 54 unidades
#   Kit de bancas: 44 unidades
#   Dashboards con Power BI: 42 unidades
#   Cubertería: 52 unidades
#   Set de ollas: 43 unidades
#   Batería: 53 unidades
#   Cuerda para saltar: 40 unidades
#   Estufa: 45 unidades
#   Cama box: 44 unidades
#   Impresora: 54 unidades
#   Mesa de noche: 56 unidades
#   Armario: 60 unidades
#   Dinosaurio Rex: 40 unidades
#   Guitarra eléctrica: 47 unidades
#   Secadora de ropa: 58 unidades
#   Sofá reclinable: 46 unidades
#   Tablet ABXY: 42 unidades
#   Cubo mágico 8x8: 44 unidades
#   Set de vasos: 41 unidades
#   Modelado predictivo: 51 unidades
#   Iphone 15: 49 unidades
#   Mochila: 39 unidades
#   Balón de baloncesto: 55 unidades
#   Auriculares con micrófono: 33 unidades
#   Sillón: 41 unidades
#   Guitarra acústica: 46 unidades
#   Iniciando en programación: 41 unidades
#   Celular ABXY: 33 unidades
#   Smartwatch: 43 unidades
#   Mesa de centro: 44 unidades
#   Cama king: 44 unidades
#   Smart TV: 44 unidades
#   Pandereta: 36 unidades
#
# Tienda 2:
#   Silla de oficina: 49 unidades
#   Pandereta: 58 unidades
#   Cama king: 45 unidades
#   Guitarra acústica: 58 unidades
#   Mochila: 45 unidades
#   Tablet ABXY: 44 unidades
#   Olla de presión: 44 unidades
#   Cubo mágico 8x8: 45 unidades
#   Secadora de ropa: 57 unidades
#   Juego de mesa: 32 unidades
#   Ajedrez de madera: 45 unidades
#   Bicicleta: 45 unidades
#   Modelado predictivo: 46 unidades
#   Dashboards con Power BI: 43 unidades
#   Cuerda para saltar: 50 unidades
#   Set de vasos: 46 unidades
#   Muñeca bebé: 48 unidades
#   Ciencia de datos con Python: 43 unidades
#   Lavavajillas: 46 unidades
#   Bloques de construcción: 54 unidades
#   Vaso térmico: 47 unidades
#   Cubertería: 39 unidades
#   Estufa: 42 unidades
#   Set de ollas: 52 unidades
#   TV LED UHD 4K: 45 unidades
#   Sillón: 35 unidades
#   Guitarra eléctrica: 47 unidades
#   Auriculares con micrófono: 44 unidades
#   Dinosaurio Rex: 42 unidades
#   Smart TV: 40 unidades
#   Armario: 54 unidades
#   Refrigerador: 49 unidades
#   Mesa de centro: 45 unidades
#   Lavadora de ropa: 49 unidades
#   Batería: 61 unidades
#   Celular ABXY: 41 unidades
#   Balón de baloncesto: 42 unidades
#   Mesa de comedor: 34 unidades
#   Kit de bancas: 45 unidades
#   Cama box: 47 unidades
#   Balón de voleibol: 46 unidades
#   Asistente virtual: 38 unidades
#   Sofá reclinable: 44 unidades
#   Carrito de control remoto: 47 unidades
#   Auriculares: 37 unidades
#   Microondas: 62 unidades
#   Smartwatch: 44 unidades
#   Iniciando en programación: 65 unidades
#   Mesa de noche: 44 unidades
#   Impresora: 34 unidades
#   Iphone 15: 55 unidades
#
# Tienda 3:
#   Secadora de ropa: 45 unidades
#   Mesa de noche: 55 unidades
#   Guitarra acústica: 47 unidades
#   Balón de voleibol: 48 unidades
#   Armario: 49 unidades
#   Impresora: 50 unidades
#   Carrito de control remoto: 52 unidades
#   Silla de oficina: 46 unidades
#   Pandereta: 51 unidades
#   Cubertería: 39 unidades
#   Muñeca bebé: 39 unidades
#   Auriculares: 43 unidades
#   Set de vasos: 36 unidades
#   TV LED UHD 4K: 42 unidades
#   Olla de presión: 47 unidades
#   Lavadora de ropa: 42 unidades
#   Set de ollas: 55 unidades
#   Dinosaurio Rex: 46 unidades
#   Modelado predictivo: 53 unidades
#   Mesa de comedor: 56 unidades
#   Dashboards con Power BI: 40 unidades
#   Kit de bancas: 57 unidades
#   Cuerda para saltar: 53 unidades
#   Iniciando en programación: 46 unidades
#   Balón de baloncesto: 50 unidades
#   Estufa: 53 unidades
#   Bicicleta: 52 unidades
#   Lavavajillas: 52 unidades
#   Smart TV: 54 unidades
#   Mochila: 36 unidades
#   Tablet ABXY: 48 unidades
#   Mesa de centro: 42 unidades
#   Cama box: 46 unidades
#   Ajedrez de madera: 47 unidades
#   Iphone 15: 46 unidades
#   Cama king: 56 unidades
#   Smartwatch: 46 unidades
#   Ciencia de datos con Python: 46 unidades
#   Refrigerador: 50 unidades
#   Auriculares con micrófono: 39 unidades
#   Juego de mesa: 52 unidades
#   Batería: 41 unidades
#   Guitarra eléctrica: 38 unidades
#   Sofá reclinable: 45 unidades
#   Sillón: 47 unidades
#   Asistente virtual: 39 unidades
#   Vaso térmico: 38 unidades
#   Celular ABXY: 44 unidades
#   Microondas: 36 unidades
#   Cubo mágico 8x8: 44 unidades
#   Bloques de construcción: 35 unidades
#
# Tienda 4:
#   Lavavajillas: 43 unidades
#   Cama box: 62 unidades
#   Balón de baloncesto: 50 unidades
#   Modelado predictivo: 50 unidades
#   Auriculares: 44 unidades
#   Refrigerador: 38 unidades
#   Guitarra eléctrica: 33 unidades
#   Auriculares con micrófono: 42 unidades
#   Iphone 15: 48 unidades
#   Mesa de noche: 55 unidades
#   Muñeca bebé: 48 unidades
#   Dashboards con Power BI: 56 unidades
#   Silla de oficina: 40 unidades
#   Kit de bancas: 42 unidades
#   Impresora: 50 unidades
#   Set de vasos: 46 unidades
#   Mesa de comedor: 55 unidades
#   Carrito de control remoto: 55 unidades
#   Cuerda para saltar: 43 unidades
#   Estufa: 47 unidades
#   Cama king: 56 unidades
#   Balón de voleibol: 48 unidades
#   Secadora de ropa: 40 unidades
#   Dinosaurio Rex: 47 unidades
#   TV LED UHD 4K: 40 unidades
#   Vaso térmico: 48 unidades
#   Smart TV: 54 unidades
#   Mesa de centro: 44 unidades
#   Tablet ABXY: 45 unidades
#   Olla de presión: 46 unidades
#   Batería: 48 unidades
#   Pandereta: 52 unidades
#   Iniciando en programación: 43 unidades
#   Juego de mesa: 48 unidades
#   Celular ABXY: 39 unidades
#   Cubertería: 59 unidades
#   Armario: 34 unidades
#   Bloques de construcción: 54 unidades
#   Bicicleta: 45 unidades
#   Asistente virtual: 50 unidades
#   Set de ollas: 50 unidades
#   Guitarra acústica: 37 unidades
#   Ajedrez de madera: 39 unidades
#   Microondas: 48 unidades
#   Smartwatch: 39 unidades
#   Mochila: 43 unidades
#   Lavadora de ropa: 38 unidades
#   Ciencia de datos con Python: 38 unidades
#   Cubo mágico 8x8: 47 unidades
#   Sillón: 45 unidades
#   Sofá reclinable: 47 unidades

# %%
import matplotlib.pyplot as plt

for tienda, productos in resultados.items():
    # Ordeno productos por cantidad (de mayor a menor)
    productos_ordenados = sorted(productos.items(), key=lambda x: x[1], reverse=True)
    nombres = [prod[0] for prod in productos_ordenados]
    valores = [prod[1] for prod in productos_ordenados]

    # Creo el gráfico
    plt.figure(figsize=(10, 5))
    plt.bar(nombres, valores, color='skyblue')
    plt.title(f'Oroductos más vendidos en {tienda}')
    plt.xlabel('Producto')
    plt.ylabel('Cantidad vendida')
    plt.xticks(rotation=90)  #para que no se solapen los nombres de los productos
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
def calcular_promedio(tienda):
  for venta in tienda.to_dict('records'):
    suma = sum(tienda["Costo de envío"])
    n = len(tienda["Costo de envío"])
  promedio = suma/n
  return round(promedio,1)


tiendas = {'Tienda 1': tienda1,'Tienda 2': tienda2,'Tienda 3': tienda3,'Tienda 4': tienda4}

print(calcular_promedio(tienda1))

promedios_envio = {nombre: calcular_promedio(datos) for nombre, datos in tiendas.items()}
print(promedios_envio)
# Out:
# 26018.6
# {'Tienda 1': 26018.6, 'Tienda 2': 25216.2, 'Tienda 3': 24805.7, 'Tienda 4': 23459.5}

# %%
import matplotlib.pyplot as plt
plt.bar(promedios_envio.keys(), promedios_envio.values(), color=['red', 'blue', 'green', 'yellow'])
plt.show()
